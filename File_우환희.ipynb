# %%
with open("demofile.txt") as f:
 print(f.readline())
 print(f.readline())

# %%
with open("demofile.txt") as f:
 print(f.read(5))

# %%
f = open("demofile.txt")
print(f.readline())
f.close()

# %%
f = open("demofile.txt")
print(f.read())

# %%
f = open("demofile.txt")
